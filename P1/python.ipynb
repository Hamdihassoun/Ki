# %% [markdown]
# # Python exercises
#
# Implement the functions according to the specifications in docstrings.
#
# Unit testing via doctest
# https://docs.python.org/3/library/doctest.html

# %%
import doctest

doctest.testmod(verbose=True)


def filter_even(l: list)->list:
    
    liste=[]
    for number in l:
        if number % 2 == 0:
            liste.append(number)

    return liste




def filter_less_than_n(l: list, n:int)->list:
    liste=[]
    for number in l:
        if number < n:
            liste.append(number)

    return liste



def remove_duplicates(l:list)->list:
  return list(set(l))




def common_elements(l1: list, l2: list)->list:
    """
    'in case we are not allowed to use set'
    
   l1 = remove_duplicates(l1)
   l2 = remove_duplicates(l2)
   common=[]
   for i in l1:
       if i in l2:
           common.append(i)
   return common"""
        
    return list(set(l1)&set(l2))




def first_and_last(l:list)->tuple:
   

    return l[0],l[-1]


def divisors(n: int)->list:
    liste =[]
    for i in range(1,int(n*0.5)+1):
        if n % i == 0:
            liste.append(i)
    liste.append(n)
    return liste


def is_prime(n: int)->bool:
    if n<=1:
        return False
    if n<4:
        return True
    if n % 2 == 0 or n % 3 == 0:
        return False
    i =5
    while i <= int(n**0.5):
        if n % i == 0 or n % (i + 2) == 0:
            return False
        i+=6
    return True





def fibonacci(n: int)->int:
    if n <= 0:
        raise ValueError("n must be a positive integer")
    if n == 1 or n==2:
        return 1
    a, b = 1, 1

    for i in range(3, n + 1):
        a, b = b, a + b
    return b



def fibonacci_series(n: int) -> list:

    if n <= 0:
        raise ValueError("n must be a positive integer")

    series = [1]
    if n == 1:
        return series
    if n == 2:
        series.append(1)
        return series
    b= 3
    while b <= n:
       series.append(fibonacci(b))
       b+=1

    return series
 


def reverse_word_order(text:str)->str:
    text =text.split(" ")
    test= "".join(text)
    return test[::-1]

#test 

print(filter_even([1,2,3,4,5]))
print(filter_less_than_n([1,2,3,4,5], 3))
print(remove_duplicates([1,1,3,3,5]))
print(common_elements([1,2,3,4,5],[1,1,3,3,5]))
print(first_and_last([1,2,3,4,5]))
print(divisors(20))
print(is_prime(97))
print(fibonacci(7))
print(fibonacci_series(7))
print(reverse_word_order("Hello world"))
# Out:
# 11 items had no tests:
#     __main__
#     __main__.common_elements
#     __main__.divisors
#     __main__.fibonacci
#     __main__.fibonacci_series
#     __main__.filter_even
#     __main__.filter_less_than_n
#     __main__.first_and_last
#     __main__.is_prime
#     __main__.remove_duplicates
#     __main__.reverse_word_order
# 0 tests in 11 items.
# 0 passed and 0 failed.
# Test passed.
# [2, 4]
# [1, 2]
# [1, 3, 5]
# [1, 3, 5]
# (1, 5)
# [1, 2, 4, 5, 10, 20]
# True
# 13
# [1, 2, 3, 5, 8, 13]
# nuossahidmah
